# %% [markdown]
# # BMS

# %%
# !nvidia-smi
import numpy as np 
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import LabelEncoder,MinMaxScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
#     Data_preprocessing

# %%
# dataloading

df = pd.read_csv('Dataset/EV_Battery_Fault_Diagnosis.csv')
df.sample(5)
dd = df[['Time (ms)','Voltage (V)','Current (A)','Temperature (°C)','Motor Speed (RPM)','Hall Code','Estimated SOC (%)','Ground Truth SOC (%)','Residual (%)']].corr()
sns.heatmap(dd)
# Out:
# <Axes: >

# %%
# groups = df.groupby('Hall Code')
# groups.groups


# df.iloc[[3, 15, 21, 44, 60, 89, 92, 94, 102, 112, 114, 120, 130],[-5,-1]]

# %%
# df.iloc[[4, 7, 12, 28, 30, 41, 52, 64, 71, 77, 82, 96, 103, 105],[-5,-1]]

# %%
# df.sample()

# %%
# data set of important features

df = df[['Voltage (V)','Current (A)','Temperature (°C)','Residual (%)','Fault Label']]
df
# Out:
#       Voltage (V)  Current (A)  Temperature (°C)  Residual (%) Fault Label
# 0            3.65         3.74              21.5           1.0      Normal
# 1            3.59         2.33              35.3           0.4      Normal
# 2            3.66         1.23              31.0           0.7      Normal
# 3            3.75         2.50              38.2           2.3     Warning
# 4            3.58         4.78              33.1           0.7      Normal
# ...           ...          ...               ...           ...         ...
# 2362         3.45         3.59              21.5           2.4     Warning
# 2363         3.71         3.04              31.0           3.2       Fault
# 2364         3.54         2.78              26.0           2.9     Warning
# 2365         3.75         4.87              34.6           2.6     Warning
# 2366         3.55         3.28              33.4           0.1      Normal
#
# [2367 rows x 5 columns]

# %%
# data spliting

X = df.iloc[:,:-1]
Y = df.iloc[:,-1]
X,Y
# Out:
# (      Voltage (V)  Current (A)  Temperature (°C)  Residual (%)
#  0            3.65         3.74              21.5           1.0
#  1            3.59         2.33              35.3           0.4
#  2            3.66         1.23              31.0           0.7
#  3            3.75         2.50              38.2           2.3
#  4            3.58         4.78              33.1           0.7
#  ...           ...          ...               ...           ...
#  2362         3.45         3.59              21.5           2.4
#  2363         3.71         3.04              31.0           3.2
#  2364         3.54         2.78              26.0           2.9
#  2365         3.75         4.87              34.6           2.6
#  2366         3.55         3.28              33.4           0.1
#
#  [2367 rows x 4 columns],
#  0        Normal
#  1        Normal
#  2        Normal
#  3       Warning
#  4        Normal
#           ...
#  2362    Warning
#  2363      Fault
#  2364    Warning
# ...

# %%
# train test splitting
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=56)
x_train.shape ,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((1893, 4), (474, 4), (1893,), (474,))

# %%
# feature scaling and class labeling
scaler = MinMaxScaler()
encoder = LabelEncoder() 

x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

y_train = encoder.fit_transform(y_train)
y_test = encoder.fit_transform(y_test)

x_train , x_test , y_train , y_test
# Out:
# (array([[0.32394366, 0.7175    , 0.43067847, 0.25      ],
#         [0.53521127, 0.49      , 0.4719764 , 0.32142857],
#         [0.66197183, 0.7975    , 0.75811209, 0.35714286],
#         ...,
#         [0.43661972, 0.735     , 0.59882006, 0.51785714],
#         [0.47887324, 0.675     , 0.53982301, 0.42857143],
#         [0.61971831, 0.6225    , 0.48672566, 0.03571429]], shape=(1893, 4)),
#  array([[0.35      , 0.78446115, 0.54654655, 0.36734694],
#         [0.45      , 0.6716792 , 0.5045045 , 0.16326531],
#         [0.48333333, 0.4887218 , 0.52252252, 0.12244898],
#         ...,
#         [0.73333333, 0.02005013, 0.41441441, 0.26530612],
#         [0.56666667, 0.13283208, 0.79279279, 0.14285714],
#         [0.68333333, 0.42105263, 0.54954955, 0.04081633]], shape=(474, 4)),
#  array([2, 2, 2, ..., 2, 2, 1], shape=(1893,)),
#  array([2, 1, 1, 1, 2, 1, 2, 2, 0, 2, 1, 2, 1, 2, 1, 2, 2, 2, 2, 1, 0, 2,
#         2, 2, 1, 2, 1, 0, 1, 1, 1, 2, 2, 2, 2, 0, 1, 2, 1, 1, 1, 2, 2, 1,
# ...

# %% [markdown]
#     Model_implementaion

# %%
# onlyscratch

# %%
# import os
# print(os.getcwd())

# %%
# print(os.listdir())
